# %% [markdown]
# <a href="https://colab.research.google.com/github/nizarmahi/Machine-Learning/blob/main/Week2P4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Langkah 0 - Install Library

# %%
# !pip install Pillow

# %% [markdown]
# # Langkah 1 - Load Image

# %%
from PIL import Image

# img = Image.open('/content/drive/MyDrive/PCVK/Images/lena.jpg')
img = Image.open('/content/image.jpeg')
img.show() # menampilkan gambar
display(img) # menampilkan gambar dalam cell
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %% [markdown]
# # Langkah 2 - Ekstrak Fitur

# %%
# Ekstrak setiap channel red, green, blue
r, g, b = img.split()

# Cek panjang ukuran channel red
print(len(r.histogram()))

# Cetak fitur histogram pada channel red
print(r.histogram())
# Out:
# 256
# ...
